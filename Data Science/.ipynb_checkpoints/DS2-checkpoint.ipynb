# %% [raw]
# pip install notebook
# after installation --in cmd --> jupyter notebook or python -m notebook

# %%
print("Hello")
# notebook is used to run code in a cell and see the output immediately below the cell.
# Out:
# Hello

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
a
# Out:
# 10

# %%
a
b
# Out:
# 20

# %% [raw]
# pip install pandas
