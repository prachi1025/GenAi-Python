# %% [markdown]
# # DataFrames

# %%
import pandas as pd

# %%
data = { 'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Age': [25, 30, 35, 40, 45], 'Department': ['HR', 'IT', 'Finance', 'Marketing', 'Operations'] }
df = pd.DataFrame(data)
df
# Out:
#       Name  Age  Department
# 0    Alice   25          HR
# 1      Bob   30          IT
# 2  Charlie   35     Finance
# 3    David   40   Marketing
# 4      Eve   45  Operations

# %% [markdown]
# # Retrieve the row of the DataFrame where the Name is 'Charlie'.

# %%
df.loc[df['Name'] == 'Charlie']
# Out:
#       Name  Age Department
# 2  Charlie   35    Finance

# %% [markdown]
# # Select all the rows where the Age is greater than 30 using loc.

# %%
df.loc[df['Age'] > 30]
# Out:
#       Name  Age  Department
# 2  Charlie   35     Finance
# 3    David   40   Marketing
# 4      Eve   45  Operations

# %% [markdown]
# # Extract the third row of the DataFrame using iloc.

# %%
df.iloc[2]
# Out:
# Name          Charlie
# Age                35
# Department    Finance
# Name: 2, dtype: object

# %% [markdown]
# # Using iloc, select the first three rows and only the Name and Age columns.

# %%
df.iloc[:3, [0,1]]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %% [markdown]
# # Change the Age of 'David' to 42 using loc.

# %%
df.loc[df['Name'] == 'David', 'Age'] = 42
df
# Out:
#       Name  Age  Department
# 0    Alice   25          HR
# 1      Bob   30          IT
# 2  Charlie   35     Finance
# 3    David   42   Marketing
# 4      Eve   45  Operations

# %% [markdown]
# # Update the Department of all employees who are in the 'IT' department to 'Tech Support'.

# %%
df.loc[df['Department'] == 'IT', 'Department'] = 'Tech Support'
df
# Out:
#       Name  Age    Department
# 0    Alice   25            HR
# 1      Bob   30  Tech Support
# 2  Charlie   35       Finance
# 3    David   42     Marketing
# 4      Eve   45    Operations

# %% [markdown]
# # Use iloc to update the Age of the second row to 32.

# %%
df.iloc[1, 1] = 32
df
# Out:
#       Name  Age    Department
# 0    Alice   25            HR
# 1      Bob   32  Tech Support
# 2  Charlie   35       Finance
# 3    David   42     Marketing
# 4      Eve   45    Operations

# %% [markdown]
# # Change the value of the Department in the first row to 'Admin' using iloc.

# %%
df.iloc[0, 2] = 'Admin'
df
# Out:
#       Name  Age    Department
# 0    Alice   25         Admin
# 1      Bob   32  Tech Support
# 2  Charlie   35       Finance
# 3    David   42     Marketing
# 4      Eve   45    Operations
